# %% [markdown]
# <a href="https://colab.research.google.com/github/ikramhasanli/demo-repo/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://cinemastercard.az/'

# %%
page = requests.get(url)


soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Baş səhifə • CineMastercard</title>
# <meta content="CinemaPlus" name="apple-mobile-web-app-title"/>
# <meta content="CinemaPlus" name="application-name"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="98wszer3jd7bo8szbpuq8kxmzum2p1" name="facebook-domain-verification"/>
# <link href="/newfav/apple-touch-icon.png?v=qA3L3XXpeA" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/newfav/favicon-32x32.png?v=qA3L3XXpeA" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/newfav/favicon-16x16.png?v=qA3L3XXpeA" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/newfav/manifest.json?v=qA3L3XXpeA" rel="manifest"/>
# <link color="#5bbad5" href="/newfav/safari-pinned-tab.svg?v=qA3L3XXpeA" rel="mask-icon"/>
# <link href="/newfav/favicon.ico?v=qA3L3XXpeA" rel="shortcut icon"/>
# <meta content="/newfav/browserconfig.xml?v=qA3L3XXpeA" name="msapplication-config"/>
# ...

# %%
soup.find('div', class_='movies container')
# Out:
# <div class="movies container">
# <div class="row">
# <div class="col-md-3 col-sm-6 col-xs-6 sortable_movie_home" data-cinema="1079" data-lang="1800">
# <div class="presale">ÖNCƏDƏN SATIŞ</div>
# <h2><a href="/az/films/evd-qalmis-2-qala-gece/">Evdə qalmış 2 (Qala Gecə)</a></h2>
# <div class="movie_image">
# <a href="/az/films/evd-qalmis-2-qala-gece/">
# <span class="movie_class">12+</span>
# <span class="favourite cc_tooltip"><span><b></b>Filmi seçilmişlərə əlavə etmək üçün\nCineClub profilinizə daxil olun</span></span>
# <div class="poster_anim"><img src="/site/assets/files/0/34/43/571/evde-qalmish-700x1000.350x0.jpg"/></div>
# </a>
# <div class="poster_icons">
# ...

# %%
soup.find('div', class_="col-md-3 col-sm-6 col-xs-6 sortable_movie_home")
# Out:
# <div class="col-md-3 col-sm-6 col-xs-6 sortable_movie_home" data-cinema="1079" data-lang="1800">
# <div class="presale">ÖNCƏDƏN SATIŞ</div>
# <h2><a href="/az/films/evd-qalmis-2-qala-gece/">Evdə qalmış 2 (Qala Gecə)</a></h2>
# <div class="movie_image">
# <a href="/az/films/evd-qalmis-2-qala-gece/">
# <span class="movie_class">12+</span>
# <span class="favourite cc_tooltip"><span><b></b>Filmi seçilmişlərə əlavə etmək üçün\nCineClub profilinizə daxil olun</span></span>
# <div class="poster_anim"><img src="/site/assets/files/0/34/43/571/evde-qalmish-700x1000.350x0.jpg"/></div>
# </a>
# <div class="poster_icons">
# ...

# %%
html_content = """
<div class="movies container">
    <caption>Movie List</caption>
</div>
"""

# %%
table = soup.find_all('div', class_='movies container')

# %%
table
# Out:
# [<div class="movies container">
#  <div class="row">
#  <div class="col-md-3 col-sm-6 col-xs-6 sortable_movie_home" data-cinema="1079" data-lang="1800">
#  <div class="presale">ÖNCƏDƏN SATIŞ</div>
#  <h2><a href="/az/films/evd-qalmis-2-qala-gece/">Evdə qalmış 2 (Qala Gecə)</a></h2>
#  <div class="movie_image">
#  <a href="/az/films/evd-qalmis-2-qala-gece/">
#  <span class="movie_class">12+</span>
#  <span class="favourite cc_tooltip"><span><b></b>Filmi seçilmişlərə əlavə etmək üçün\nCineClub profilinizə daxil olun</span></span>
#  <div class="poster_anim"><img src="/site/assets/files/0/34/43/571/evde-qalmish-700x1000.350x0.jpg"/></div>
#  </a>
#  <div class="poster_icons">
# ...

# %%
movie_names = soup.find_all('h2')
for h2 in movie_names:
    links = h2.find_all('a')
    for link in links:
        print(link['href'], link.text)
# Out:
# /az/films/evd-qalmis-2-qala-gece/ Evdə qalmış 2 (Qala Gecə)
# /az/films/evde-qalmis-2/ Evdə qalmış 2
# /az/films/ovcu-kraven/ Ovçu Kreyven
# /az/films/moana-2/ Moana 2
# /az/films/paddinqtonun-mac-ralari-3/ Paddinqton 3
# /az/films/tagiyev-neft/ Tağıyev: Neft
# /az/films/qladiator-2/ Qladiator 2
# /az/films/s-riyy/ Səriyyə
# /az/films/missiya-qirmizi/ Missiya: Qırmızı
# /az/films/0000-kilometre/ 0000 Kilometre
# /az/films/hozu-007/ Hozu 007
# /az/films/uzukl-rin-hokmdari-rohirriml-rin-muharib-si/ Üzüklərin hökmdarı: Rohirrimlərin Müharibəsi
# /az/films/q-z-bli-cadug-r/ Qəzəbli Cadugər
# /az/films/dabba/ Dabba
# /az/films/ruhlarin-dasiyicisi/ Ruhların daşıyıcısı
# /az/films/uc-pisik-qis-t-tili/ Üç Pişik. Qış Tətili
# /az/films/qapi/ Qapı
# /az/films/evd-qalmis-2-qala-gece/ Evdə qalmış 2 (Qala Gecə)
# /az/films/evde-qalmis-2/ Evdə qalmış 2
# /az/coming-soon/mufasa-aslanlar-krali/ Mufasa: Aslan Kral
# /az/coming-soon/sonic-the-hedgehog-3/ Sonik 3
# ...

# %%
movie_names
# Out:
# [<h2><a href="/az/films/evd-qalmis-2-qala-gece/">Evdə qalmış 2 (Qala Gecə)</a></h2>,
#  <h2><a href="/az/films/evde-qalmis-2/">Evdə qalmış 2</a></h2>,
#  <h2><a href="/az/films/ovcu-kraven/">Ovçu Kreyven</a></h2>,
#  <h2><a href="/az/films/moana-2/">Moana 2</a></h2>,
#  <h2><a href="/az/films/paddinqtonun-mac-ralari-3/">Paddinqton 3</a></h2>,
#  <h2><a href="/az/films/tagiyev-neft/">Tağıyev: Neft</a></h2>,
#  <h2><a href="/az/films/qladiator-2/">Qladiator 2</a></h2>,
#  <h2><a href="/az/films/s-riyy/">Səriyyə</a></h2>,
#  <h2><a href="/az/films/missiya-qirmizi/">Missiya: Qırmızı</a></h2>,
#  <h2><a href="/az/films/0000-kilometre/">0000 Kilometre</a></h2>,
#  <h2><a href="/az/films/hozu-007/">Hozu 007</a></h2>,
#  <h2><a href="/az/films/uzukl-rin-hokmdari-rohirriml-rin-muharib-si/">Üzüklərin hökmdarı: Rohirrimlərin Müharibəsi</a></h2>,
#  <h2><a href="/az/films/q-z-bli-cadug-r/">Qəzəbli Cadugər</a></h2>,
#  <h2><a href="/az/films/dabba/">Dabba</a></h2>,
# ...

# %%
movie_names_table =  [title.text.strip() for title in movie_names]
print(movie_names_table)
# Out:
# ['Evdə qalmış 2 (Qala Gecə)', 'Evdə qalmış 2', 'Ovçu Kreyven', 'Moana 2', 'Paddinqton 3', 'Tağıyev: Neft', 'Qladiator 2', 'Səriyyə', 'Missiya: Qırmızı', '0000 Kilometre', 'Hozu 007', 'Üzüklərin hökmdarı: Rohirrimlərin Müharibəsi', 'Qəzəbli Cadugər', 'Dabba', 'Ruhların daşıyıcısı', 'Üç Pişik. Qış Tətili', 'Qapı', 'Evdə qalmış 2 (Qala Gecə)', 'Evdə qalmış 2', 'Mufasa: Aslan Kral', 'Sonik 3', 'Daha yaxşı olmaq: Robbi Uilyamsın Hekayəsi', 'Şahzadə İvan və Boz Canavar 6', 'Nosferatu', 'Oğrulara Qarşı 2', 'Xüsusi təhlükəli sərnişin', 'Mikki 17']

# %%
import pandas as pd

# %%
df = pd.DataFrame(data = movie_names_table, columns = ["movie_names"])
df
# Out:
#                                      movie_names
# 0                      Evdə qalmış 2 (Qala Gecə)
# 1                                  Evdə qalmış 2
# 2                                   Ovçu Kreyven
# 3                                        Moana 2
# 4                                   Paddinqton 3
# 5                                  Tağıyev: Neft
# 6                                    Qladiator 2
# 7                                        Səriyyə
# 8                               Missiya: Qırmızı
# 9                                 0000 Kilometre
# 10                                      Hozu 007
# 11  Üzüklərin hökmdarı: Rohirrimlərin Müharibəsi
# 12                               Qəzəbli Cadugər
# 13                                         Dabba
# 14                           Ruhların daşıyıcısı
# 15                          Üç Pişik. Qış Tətili
# 16                                          Qapı
# 17                     Evdə qalmış 2 (Qala Gecə)
# ...

# %%
badambura_all_urls = [
    "https://cinemastercard.az/az/films/evd-qalmis-2-qala-gece/",
    "https://cinemastercard.az/az/films/evde-qalmis-2/",
    "https://cinemastercard.az/az/films/ovcu-kraven/",
    "https://cinemastercard.az/az/films/moana-2/",
    "https://cinemastercard.az/az/films/paddinqtonun-mac-ralari-3/",
    "https://cinemastercard.az/az/films/tagiyev-neft/",
    "https://cinemastercard.az/az/films/qladiator-2/",
    "https://cinemastercard.az/az/films/s-riyy/",
    "https://cinemastercard.az/az/films/missiya-qirmizi/",
    "https://cinemastercard.az/az/films/0000-kilometre/",
    "https://cinemastercard.az/az/films/hozu-007/",
    "https://cinemastercard.az/az/films/uzukl-rin-hokmdari-rohirriml-rin-muharib-si/",
    "https://cinemastercard.az/az/films/q-z-bli-cadug-r/",
    "https://cinemastercard.az/az/films/dabba/",
    "https://cinemastercard.az/az/films/ruhlarin-dasiyicisi/",
    "https://cinemastercard.az/az/films/uc-pisik-qis-t-tili/",
    "https://cinemastercard.az/az/films/qapi/",
    "https://cinemastercard.az/az/films/evd-qalmis-2-qala-gece/",
    "https://cinemastercard.az/az/films/evde-qalmis-2/",
    "https://cinemastercard.az/az/coming-soon/mufasa-aslanlar-krali/",
    "https://cinemastercard.az/az/coming-soon/sahzad-i-van-v-boz-canavar-6/",
    "https://cinemastercard.az/az/coming-soon/sonic-the-hedgehog-3/",
    "https://cinemastercard.az/az/coming-soon/daha-yaxsi-olmaq-robbi-uilyamsin-hekay-si/",
    "https://cinemastercard.az/az/coming-soon/nosferatu/",
    "https://cinemastercard.az/az/coming-soon/ogrulara-qarsi-2/",
    "https://cinemastercard.az/az/coming-soon/xususi-t-hluk-li-s-rnisin/",
    "https://cinemastercard.az/az/coming-soon/mikki-17/"
    ]
def scrape_ind_row_data(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html')
    column_data = soup.find_all('ul')

    for i, row in enumerate(column_data):
        row_data = row.find_all('div')
        ind_row_data = [data.text.strip() for data in row_data]

        if i == 7:
            return ind_row_data
    return []

def each_row_in_the_list(badambura_all_urls):
  result = []
  for i in badambura_all_urls:
    result.append(scrape_ind_row_data(i))
  return pd.Series(result)

combined_results = pd.Series(each_row_in_the_list(badambura_all_urls))

print(combined_results)
# Out:
# 0     [Film 2D formatında nümayiş olunurFilm Azərbay...
# 1     [Film 2D formatında nümayiş olunurFilm Azərbay...
# 2     [Film 2D formatında nümayiş olunurFilm Azərbay...
# 3     [Film 3D formatında nümayiş olunurFilm 2D form...
# 4     [Film 2D formatında nümayiş olunurFilm Azərbay...
# 5     [Film 2D formatında nümayiş olunurFilm Azərbay...
# 6     [Film 2D formatında nümayiş olunurFilm Azərbay...
# 7     [Film 2D formatında nümayiş olunurFilm Azərbay...
# 8     [Film 2D formatında nümayiş olunurFilm Azərbay...
# 9     [Film 2D formatında nümayiş olunurFilm Azərbay...
# 10    [Film 2D formatında nümayiş olunurFilm Azərbay...
# 11    [Film 2D formatında nümayiş olunurFilm Azərbay...
# 12    [Film 2D formatında nümayiş olunurFilm Azərbay...
# 13    [Film 2D formatında nümayiş olunurFilm Azərbay...
# 14    [Film 2D formatında nümayiş olunurFilm Azərbay...
# 15    [Film 2D formatında nümayiş olunurFilm Azərbay...
# 16    [Film 2D formatında nümayiş olunurFilm Azərbay...
# ...

# %%
df = pd.DataFrame(columns = ["movie_name", "movie_filters", "on_screen_dates", "country_producde", "director", "cast", "movie_len", "movie_genre", "movie_age_limit"])
df
# Out:
# Empty DataFrame
# Columns: [movie_name, movie_filters, on_screen_dates, country_producde, director, cast, movie_len, movie_genre, movie_age_limit]
# Index: []

# %%
badambura_all_urls = [
    "https://cinemastercard.az/az/films/evd-qalmis-2-qala-gece/",
    "https://cinemastercard.az/az/films/evde-qalmis-2/",
    "https://cinemastercard.az/az/films/ovcu-kraven/",
    "https://cinemastercard.az/az/films/moana-2/",
    "https://cinemastercard.az/az/films/paddinqtonun-mac-ralari-3/",
    "https://cinemastercard.az/az/films/tagiyev-neft/",
    "https://cinemastercard.az/az/films/qladiator-2/",
    "https://cinemastercard.az/az/films/s-riyy/",
    "https://cinemastercard.az/az/films/missiya-qirmizi/",
    "https://cinemastercard.az/az/films/0000-kilometre/",
    "https://cinemastercard.az/az/films/hozu-007/",
    "https://cinemastercard.az/az/films/uzukl-rin-hokmdari-rohirriml-rin-muharib-si/",
    "https://cinemastercard.az/az/films/q-z-bli-cadug-r/",
    "https://cinemastercard.az/az/films/dabba/",
    "https://cinemastercard.az/az/films/ruhlarin-dasiyicisi/",
    "https://cinemastercard.az/az/films/uc-pisik-qis-t-tili/",
    "https://cinemastercard.az/az/films/qapi/",
    "https://cinemastercard.az/az/films/evd-qalmis-2-qala-gece/",
    "https://cinemastercard.az/az/films/evde-qalmis-2/",
    "https://cinemastercard.az/az/coming-soon/mufasa-aslanlar-krali/",
    "https://cinemastercard.az/az/coming-soon/sahzad-i-van-v-boz-canavar-6/",
    "https://cinemastercard.az/az/coming-soon/sonic-the-hedgehog-3/",
    "https://cinemastercard.az/az/coming-soon/daha-yaxsi-olmaq-robbi-uilyamsin-hekay-si/",
    "https://cinemastercard.az/az/coming-soon/nosferatu/",
    "https://cinemastercard.az/az/coming-soon/ogrulara-qarsi-2/",
    "https://cinemastercard.az/az/coming-soon/xususi-t-hluk-li-s-rnisin/",
    "https://cinemastercard.az/az/coming-soon/mikki-17/"
    ]
def scrape_ind_row_data(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html')
    column_data = soup.find_all('ul')

    for i, row in enumerate(column_data):
        row_data = row.find_all('div')
        ind_row_data = [data.text.strip() for data in row_data]

        if i == 7:
            return ind_row_data
    return []

def each_row_in_the_list(badambura_all_urls):
  result = []
  for i in badambura_all_urls:
    result.append(scrape_ind_row_data(i))
  return pd.Series(result)

combined_results = pd.Series(each_row_in_the_list(badambura_all_urls))
df = pd.DataFrame(columns = ["movie_name", "movie_filters", "on_screen", "country_produced", "director", "cast", "movie_len", "movie_genre", "movie_age_limit"])

movie_filters = [row[0] if row else None for row in combined_results]
on_screen = [row[1] if row else None for row in combined_results]
country_produced = [row[2] if row else None for row in combined_results]
director = [row[3] if row else None for row in combined_results]
cast = [row[4] if row else None for row in combined_results]
movie_len = [row[5] if row else None for row in combined_results]
movie_genre = [row[6] if row else None for row in combined_results]
movie_age_limit = [row[7] if row else None for row in combined_results]
df['movie_filters'] = movie_filters
df["movie_name"] = movie_names_table
df["on_screen"] = on_screen
df["country_produced"] = country_produced
df["director"] = director
df["cast"] = cast
df["movie_len"] = movie_len
df["movie_genre"] = movie_genre
df["movie_age_limit"] = movie_age_limit

# %%
df.drop(index=[17, 18], inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                       movie_name  \
# 0                      Evdə qalmış 2 (Qala Gecə)
# 1                                  Evdə qalmış 2
# 2                                   Ovçu Kreyven
# 3                                        Moana 2
# 4                                   Paddinqton 3
# 5                                  Tağıyev: Neft
# 6                                    Qladiator 2
# 7                                        Səriyyə
# 8                               Missiya: Qırmızı
# 9                                 0000 Kilometre
# 10                                      Hozu 007
# 11  Üzüklərin hökmdarı: Rohirrimlərin Müharibəsi
# 12                               Qəzəbli Cadugər
# 13                                         Dabba
# 14                           Ruhların daşıyıcısı
# 15                          Üç Pişik. Qış Tətili
# 16                                          Qapı
# 17    Daha yaxşı olmaq: Robbi Uilyamsın Hekayəsi
# ...

# %%
df.to_csv('cinemaplus_data.csv', index=False)

# %%
combined_results[0]
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan dilində nümayiş olunur',
#  '13.12.2024 - 08.01.2025',
#  'Azərbaycan',
#  'Valeh Əhmədov',
#  'Həmidə Ömərova, Şəhriyar Əbilov, Kəmalə Piriyeva, Kənan Yusifov, Sanura Cəfərova',
#  '100 dəqiqə',
#  'Romantik komediya',
#  '12+']

# %%
ind1_url = "https://cinemastercard.az/az/films/evd-qalmis-2-qala-gece/"

page = requests.get(ind1_url)


soup_ind1 = BeautifulSoup(page.text, 'html')

column_data1 = soup_ind1.find_all('ul')

for i, row in enumerate(column_data1):
    row_data = row.find_all('div')
    ind_row_data1 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data1)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan dilində nümayiş olunur', '13.12.2024 - 08.01.2025', 'Azərbaycan', 'Valeh Əhmədov', 'Həmidə Ömərova, Şəhriyar Əbilov, Kəmalə Piriyeva, Kənan Yusifov, Sanura Cəfərova', '100 dəqiqə', 'Romantik komediya', '12+']

# %%
ind2_url = "https://cinemastercard.az/az/films/evde-qalmis-2/"

page = requests.get(ind2_url)

soup_ind2 = BeautifulSoup(page.text, 'html')

column_data2 = soup_ind2.find_all('ul')

for i, row in enumerate(column_data2):
    row_data = row.find_all('div')
    ind_row_data2 = [data.text.strip() for data in row_data]

    if i == 7:
      print(ind_row_data2)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan dilində nümayiş olunur', '13.12.2024 - 08.01.2025', 'Azərbaycan', 'Valeh Əhmədov', 'Həmidə Ömərova, Şəhriyar Əbilov, Kəmalə Piriyeva, Kənan Yusifov, Sanura Cəfərova', '95 dəqiqə', 'Romantik komediya', '12+']

# %%
ind3_url = "https://cinemastercard.az/az/films/moana-2/"

page = requests.get(ind3_url)

soup_ind3 = BeautifulSoup(page.text, 'html')

column_data3 = soup_ind3.find_all('ul')

for i, row in enumerate(column_data3):
    row_data = row.find_all('div')
    ind_row_data3 = [data.text.strip() for data in row_data]

    if i == 7:
      print(ind_row_data3)
# Out:
# ['Film 3D formatında nümayiş olunurFilm 2D formatında nümayiş olunurFilm Azərbaycan subtitrları ilə nümayiş olunurFilm 4DX formatında nümayiş olunurFilm Rus dilində nümayiş olunurFilm İngilis dilində nümayiş olunurFilm Türk dilində nümayiş olunur', '28.11.2024 - 25.12.2024', 'ABŞ, Kanada', 'Devid Derrik, Ceyson Hend, Dena Ledu Miller', 'Auli Kravalo, Dueyn Conson, Alan Tyudik', '115 dəqiqə', 'cizgi filmi, fentezi, komediya', '6+']

# %%
ind4_url = "https://cinemastercard.az/az/films/paddinqtonun-mac-ralari-3/"

page = requests.get(ind4_url)

soup_ind4 = BeautifulSoup(page.text, 'html')

column_data4 = soup_ind4.find_all('ul')

for i, row in enumerate(column_data4):
    row_data = row.find_all('div')
    ind_row_data4 = [data.text.strip() for data in row_data]

    if i == 7:
      print(ind_row_data4)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan dilində nümayiş olunur', '28.11.2024 - 25.12.2024', 'Böyük Britaniya, Fransa', 'Daqal Vilson', 'Ben Vinşou, Emili Mortimer, Olivia Kolman', '120 dəqiqə', 'komediya, macəra, ailəvi', '6+']

# %%
ind5_url = "https://cinemastercard.az/az/films/tagiyev-neft/"

page = requests.get(ind5_url)

soup_ind5 = BeautifulSoup(page.text, 'html')

column_data5 = soup_ind5.find_all('ul')

for i, row in enumerate(column_data5):
    row_data = row.find_all('div')
    ind_row_data5 = [data.text.strip() for data in row_data]

    if i == 7:
      print(ind_row_data5)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan dilində nümayiş olunur', '07.11.2024 - 25.12.2024', 'Azərbaycan', 'Zaur Qasımlı', 'Pərviz Məmmədrzayev, Qurban İsmayılov, Manaf Süleymanov', '120 dəqiqə', 'Tarixi, Bioqrafik', '6+']

# %%
ind6_url = "https://cinemastercard.az/az/films/qladiator-2/"

page = requests.get(ind6_url)

soup_ind6 = BeautifulSoup(page.text, 'html')

column_data6 = soup_ind6.find_all('ul')

for i, row in enumerate(column_data6):
    row_data = row.find_all('div')
    ind_row_data6 = [data.text.strip() for data in row_data]

    if i == 7:
      print(ind_row_data6)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan subtitrları ilə nümayiş olunurFilm Screen X formatında nümayiş olunurFilm Rus dilində nümayiş olunurFilm Türk dilində nümayiş olunur', '14.11.2024 - 25.12.2024', 'Böyük Britaniya, ABŞ', 'Ridli Skott', 'Pedro Paskal, Denzel Vaşinqton, Cozef Kuin', '165 dəqiqə', 'Döyüş filmi, dram, macəra', '18+']

# %%
ind7_url = "https://cinemastercard.az/az/films/s-riyy/"

page = requests.get(ind7_url)

soup_ind7 = BeautifulSoup(page.text, 'html')

column_data7 = soup_ind7.find_all('ul')

for i, row in enumerate(column_data7):
    row_data = row.find_all('div')
    ind_row_data7 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data7)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan dilində nümayiş olunur', '29.11.2024 - 26.12.2024', 'Azərbaycan', 'Əlixan Rəcəbov', 'Nəzakət Heydərova , Niyaz İlyasoğlu  ,Əlixan Rəcəbov , Günay Əhməd , İbrahim Laçın , Nazlı Quliyeva', '95 dəqiqə', 'Satirik komediya', '18+']

# %%
ind8_url = "https://cinemastercard.az/az/films/missiya-qirmizi/"

page = requests.get(ind8_url)

soup_ind8 = BeautifulSoup(page.text, 'html')

column_data8 = soup_ind8.find_all('ul')

for i, row in enumerate(column_data8):
    row_data = row.find_all('div')
    ind_row_data8 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data8)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan subtitrları ilə nümayiş olunurFilm Rus dilində nümayiş olunur', '07.11.2024 - 18.12.2024', 'ABŞ', 'Ceyk Kezdan', 'Dueyn Conson, Kris Evans, Lüsi Lyu', '140 dəqiqə', 'Fentezi, döyüş filmi, komediya', '12+']

# %%
ind9_url = "https://cinemastercard.az/az/films/0000-kilometre/"

page = requests.get(ind9_url)

soup_ind9 = BeautifulSoup(page.text, 'html')

column_data9 = soup_ind9.find_all('ul')

for i, row in enumerate(column_data9):
    row_data = row.find_all('div')
    ind_row_data9 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data9)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan subtitrları ilə nümayiş olunurFilm Türk dilində nümayiş olunur', '01.11.2024 - 25.12.2024', 'Türkiyə', 'Deniz Enyüksek', 'Derya Pınar Ak, Ahmet Haktan Zavlak, Gülin İyigün', '125 dəqiqə', 'Dram, romantik', '16+']

# %%
ind10_url = "https://cinemastercard.az/az/films/hozu-007/"

page = requests.get(ind10_url)

soup_ind10 = BeautifulSoup(page.text, 'html')

column_data10 = soup_ind10.find_all('ul')

for i, row in enumerate(column_data10):
    row_data = row.find_all('div')
    ind_row_data10 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data10)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan dilində nümayiş olunur', '31.10.2024 - 25.12.2024', 'Azərbaycan', 'İlham Yaşaroğlu', 'Məcid Hüseynov, Mark Kim, Aqil M. Quliyev', '105 dəqiqə', 'Komediya', '12+']

# %%
ind11_url = "https://cinemastercard.az/az/films/q-z-bli-cadug-r/"

page = requests.get(ind11_url)

soup_ind11 = BeautifulSoup(page.text, 'html')

column_data11 = soup_ind11.find_all('ul')

for i, row in enumerate(column_data11):
    row_data = row.find_all('div')
    ind_row_data11 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data11)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan subtitrları ilə nümayiş olunurFilm 3D formatında nümayiş olunurFilm Rus dilində nümayiş olunurFilm İngilis dilində nümayiş olunur', '21.11.2024 - 18.12.2024', 'ABŞ', 'Con M. Çu', 'Sintiya Erivo, Ariana Qrande, Conatan Beyli', '175 dəqiqə', 'Müzikl, fentezi, melodram', '12+']

# %%
ind13_url = "https://cinemastercard.az/az/films/dabba/"

page = requests.get(ind13_url)

soup_ind13 = BeautifulSoup(page.text, 'html')

column_data13 = soup_ind13.find_all('ul')

for i, row in enumerate(column_data13):
    row_data = row.find_all('div')
    ind_row_data13 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data13)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan subtitrları ilə nümayiş olunurFilm Türk dilində nümayiş olunur', '05.12.2024 - 15.01.2025', 'Türkiyə', 'Anastasiya Budakva', 'Harun Doğan, Hande Sude Alınca, Emirhan Parlak', '90 dəqiqə', 'Qorxu', '18+']

# %%
ind16_url = "https://cinemastercard.az/az/films/ruhlarin-dasiyicisi/"

page = requests.get(ind16_url)

soup_ind16 = BeautifulSoup(page.text, 'html')

column_data16 = soup_ind16.find_all('ul')

for i, row in enumerate(column_data16):
    row_data = row.find_all('div')
    ind_row_data16 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data16)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan subtitrları ilə nümayiş olunurFilm Rus dilində nümayiş olunur', '05.12.2024 - 07.01.2025', 'ABŞ', 'Brüs Qudison', 'Corc Bukari, Nik Frost, Sinnöve Karlsen', '105 dəqiqə', 'Qorxu, Triller', '18+']

# %%
ind18_url = "https://cinemastercard.az/az/films/qapi/"

page = requests.get(ind18_url)

soup_ind18 = BeautifulSoup(page.text, 'html')

column_data18 = soup_ind18.find_all('ul')

for i, row in enumerate(column_data18):
    row_data = row.find_all('div')
    ind_row_data18 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data18)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan dilində nümayiş olunur', '10.10.2024 - 25.12.2024', 'Azərbaycan', 'Vüsal Əhmədzadə', 'Rafael İsgəndərov,Nurlan Rüstəmov,Taleh Yüzbəyov,Sənubər İsgəndərli,Kəmalə Piriyeva,Kamran Ağabalayev,Zemfira Əbdülsəmədova,Emil Musayev,İlkin Xəlil', '105 dəqiqə', 'Kriminal,Traqikomediya', '18+']

# %%
ind19_url = "https://cinemastercard.az/az/films/evd-qalmis-2-qala-gece/"

page = requests.get(ind19_url)

soup_ind19 = BeautifulSoup(page.text, 'html')

column_data19 = soup_ind19.find_all('ul')

for i, row in enumerate(column_data19):
    row_data = row.find_all('div')
    ind_row_data19 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data19)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan dilində nümayiş olunur', '13.12.2024 - 08.01.2025', 'Azərbaycan', 'Valeh Əhmədov', 'Həmidə Ömərova, Şəhriyar Əbilov, Kəmalə Piriyeva, Kənan Yusifov, Sanura Cəfərova', '100 dəqiqə', 'Romantik komediya', '12+']

# %%
ind24_url = "https://cinemastercard.az/az/coming-soon/mufasa-aslanlar-krali/"

page = requests.get(ind24_url)

soup_ind24 = BeautifulSoup(page.text, 'html')

column_data24 = soup_ind24.find_all('ul')

for i, row in enumerate(column_data24):
    row_data = row.find_all('div')
    ind_row_data24 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data24)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan subtitrları ilə nümayiş olunurFilm Rus dilində nümayiş olunur', '19.12.2024 - 22.01.2025', 'ABŞ', 'Barri Cenkins', 'Aron Pier, Donald Qlover, Kelvin Harrison', '135 dəqiqə', 'cizgi filmi, macəra, ailəvi', '6+']

# %%
ind25_url = "https://cinemastercard.az/az/coming-soon/sonic-the-hedgehog-3/"

page = requests.get(ind25_url)

soup_ind25 = BeautifulSoup(page.text, 'html')

column_data25 = soup_ind25.find_all('ul')

for i, row in enumerate(column_data25):
    row_data = row.find_all('div')
    ind_row_data25 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data25)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan subtitrları ilə nümayiş olunurFilm Rus dilində nümayiş olunur', '26.12.2024 - 29.01.2025', 'ABŞ, Yaponiya', 'Ceff Fauler', 'Ben Kollin, İdris Elba, Kollin Oşonessi', 'dəqiqə', 'Fentezi, komediya, macəra', '6+']

# %%
ind26_url = "https://cinemastercard.az/az/coming-soon/daha-yaxsi-olmaq-robbi-uilyamsin-hekay-si/"

page = requests.get(ind26_url)

soup_ind26 = BeautifulSoup(page.text, 'html')

column_data26 = soup_ind26.find_all('ul')

for i, row in enumerate(column_data26):
    row_data = row.find_all('div')
    ind_row_data26 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data26)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan subtitrları ilə nümayiş olunurFilm Rus dilində nümayiş olunur', '26.12.2024 - 29.01.2025', 'Avstraliya, Çin, Fransa, Böyük Britaniya, ABŞ', 'Maykl Qreysi', 'Robbi Uilyams, Conno Devis, Stiv Pemberton', '150 dəqiqə', 'Müzikl, Fentezi, Bioqrafiya', '18+']

# %%
ind27_url = "https://cinemastercard.az/az/coming-soon/nosferatu/"

page = requests.get(ind27_url)

soup_ind27 = BeautifulSoup(page.text, 'html')

column_data27 = soup_ind27.find_all('ul')

for i, row in enumerate(column_data27):
    row_data = row.find_all('div')
    ind_row_data27 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data27)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan subtitrları ilə nümayiş olunurFilm Rus dilində nümayiş olunur', '02.01.2025 - 31.01.2025', 'ABŞ', 'Robert Eqqers', 'Emma Korrin, Aaron Teylor-Conson, Bill Skarsqard', '150 dəqiqə', 'Qorxu, melodrama', '+']

# %%
ind28_url = "https://cinemastercard.az/az/coming-soon/ogrulara-qarsi-2/"

page = requests.get(ind28_url)

soup_ind28 = BeautifulSoup(page.text, 'html')

column_data28 = soup_ind28.find_all('ul')

for i, row in enumerate(column_data28):
    row_data = row.find_all('div')
    ind_row_data28 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data28)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan subtitrları ilə nümayiş olunurFilm Rus dilində nümayiş olunur', '09.01.2025 - 12.02.2025', 'ABŞ, Kanada, İspaniya', 'Kristian Qyudqest', 'Cerard Batler, O Şi Cekson kiçik, Cordan Brices', '135 dəqiqə', 'Döyüş filmi, triller, dram, kriminal', '16+']

# %%
ind29_url = "https://cinemastercard.az/az/coming-soon/xususi-t-hluk-li-s-rnisin/"

page = requests.get(ind29_url)

soup_ind29 = BeautifulSoup(page.text, 'html')

column_data29 = soup_ind29.find_all('ul')

for i, row in enumerate(column_data29):
    row_data = row.find_all('div')
    ind_row_data29 = [data.text.strip() for data in row_data]

    if i == 7:
        print(ind_row_data29)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan subtitrları ilə nümayiş olunurFilm Rus dilində nümayiş olunur', '23.01.2025 - 18.02.2025', 'ABŞ', 'Mel Qibson', 'Mark Uolberq, Mişel Dokeri, Tofer Qreys', '100 dəqiqə', 'Döyüş, triller, dram, kriminal', '+']

# %%
ind30_url = "https://cinemastercard.az/az/coming-soon/mikki-17/"

page = requests.get(ind30_url)

soup_ind30 = BeautifulSoup(page.text, 'html')

column_data30 = soup_ind30.find_all('ul')

for i, row in enumerate(column_data30):
    row_data = row.find_all('div')
    ind_row_data30 = [data.text.strip() for data in row_data]

    if i == 7:
      print(ind_row_data30)
# Out:
# ['Film 2D formatında nümayiş olunurFilm Azərbaycan subtitrları ilə nümayiş olunurFilm Rus dilində nümayiş olunur', '18.04.2025 - 14.05.2025', 'ABŞ, Cənubi Koreya', 'Pon Cun-ho', 'Robert Pattinson, Toni Kollett, Mark Ruffalo', '160 dəqiqə', 'Fantastika, komediya, macəra', '18+']

# %%
print(ind_row_data30)
# Out:
# []
